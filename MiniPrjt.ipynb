# %% [markdown]
# <a href="https://colab.research.google.com/github/NishaS1014/Data-Analytics-using-colab/blob/main/MiniPrjt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt

uploaded=files.upload()

df=pd.read_csv("customers 30.csv")
print(df)
# Out:
#      <input type="file" id="files-744de975-5599-4cf8-9213-ec319e801f56" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-744de975-5599-4cf8-9213-ec319e801f56">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(df.head())
# Out:
#    idex Customer Id  First Name Last Name  Company         City Country
# 0     1  deejjuf8047     andrew   goodman   "terry  north angel   macao
# 1     2   hhtuh47938      alvin      lane      "yu     lake don   china
# 2     3  v574ke949lh      jenna   harding  "french      rowland   nepal
# 3     4  wbjh3892jel   fernando      ford    "moon        sharp   sudan
# 4     5  58djkjiw93m       kara     woods  may lnc    wst devon     uae

# %%
Total_malename = df["First Name"].sum()
print("Total Malename:",Total_malename)
# Out:
# Total Malename: andrewalvinjennafernandokaramarrisajulielaurenemilymarienicholebernarddarryIRyanvickiseansophiahelenjoannthomascristinavickiglenndariusxavierdouglasebonytylercesardarrel

# %%
Country_name = df.groupby("First Name")["Country"].count()
print(Country_name)
# Out:
# First Name
# Ryan        1
# alvin       1
# andrew      1
# bernard     1
# cesar       1
# cristina    1
# darius      1
# darrel      1
# darryI      1
# douglas     1
# ebony       1
# emily       1
# fernando    1
# glenn       1
# helen       1
# jenna       1
# joann       1
# julie       1
# kara        1
# lauren      1
# marie       1
# marrisa     1
# nichole     1
# sean        1
# sophia      1
# thomas      1
# tyler       1
# vicki       2
# xavier      1
# Name: Country, dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   idex          30 non-null     int64
#  1   Customer Id   30 non-null     object
#  2   First Name    30 non-null     object
#  3   Last Name     30 non-null     object
#  4   Company       30 non-null     object
#  5   City          30 non-null     object
#  6   Country       30 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.8+ KB
# None

# %%
print(df.shape)
# Out:
# (30, 7)

# %%
print(df.isnull().sum())
# Out:
# idex            0
# Customer Id     0
# First Name      0
# Last Name       0
# Company         0
# City            0
# Country         0
# dtype: int64
