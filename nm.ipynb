# %% [markdown]
# <a href="https://colab.research.google.com/github/NishaS1014/Data-Analytics-using-colab/blob/main/nm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

years=[2021,2022,2023,2024,2025,2026]
sales=[12000,13000,5000,33000,37000,56000]

plt.plot(years,sales)
plt.title("Yearly Sales")
plt.xlabel("years")
plt.ylabel("Sales Amount")
plt.show()
